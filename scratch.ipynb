# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\SURYA
# [nltk_data]     MANOJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\SURYA
# [nltk_data]     MANOJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize
import re
import heapq

# %%
text ='''Data science combines math and statistics, specialized programming, advanced analytics, artificial intelligence (AI) and machine learning with specific subject matter expertise to uncover actionable insights hidden in an organization’s data. These insights can be used to guide decision making and strategic planning.

The accelerating volume of data sources, and subsequently data, has made data science is one of the fastest growing field across every industry. As a result, it is no surprise that the role of the data scientist was dubbed the “sexiest job of the 21st century” by Harvard Business Review. Organizations are increasingly reliant on them to interpret data and provide actionable recommendations to improve business outcomes.

The data science lifecycle involves various roles, tools, and processes, which enables analysts to glean actionable insights. Typically, a data science project undergoes the following stages:

Data ingestion: The lifecycle begins with the data collection, both raw structured and unstructured data from all relevant sources using a variety of methods. These methods can include manual entry, web scraping, and real-time streaming data from systems and devices. Data sources can include structured data, such as customer data, along with unstructured data like log files, video, audio, pictures, the Internet of Things (IoT), social media, and more.
Data storage and data processing: Since data can have different formats and structures, companies need to consider different storage systems based on the type of data that needs to be captured. Data management teams help to set standards around data storage and structure, which facilitate workflows around analytics, machine learning and deep learning models. This stage includes cleaning data, deduplicating, transforming and combining the data using ETL (extract, transform, load) jobs or other data integration technologies. This data preparation is essential for promoting data quality before loading into a data warehouse, data lake, or other repository.
Data analysis: Here, data scientists conduct an exploratory data analysis to examine biases, patterns, ranges, and distributions of values within the data. This data analytics exploration drives hypothesis generation for a/b testing. It also allows analysts to determine the data’s relevance for use within modeling efforts for predictive analytics, machine learning, and/or deep learning. Depending on a model’s accuracy, organizations can become reliant on these insights for business decision making, allowing them to drive more scalability.
Communicate: Finally, insights are presented as reports and other data visualizations that make the insights and their impact on business easier for business analysts and other decision-makers to understand. A data science programming language such as R or Python includes components for generating visualizations; alternately, data scientists can use dedicated visualization tools.'''

# %%
clean_text = re.sub(r'\[[0-9]*\]','',text)

# %%
sentences = sent_tokenize(clean_text)
print(sentences)
# Out:
# ['Data science combines math and statistics, specialized programming, advanced analytics, artificial intelligence (AI) and machine learning with specific subject matter expertise to uncover actionable insights hidden in an organization’s data.', 'These insights can be used to guide decision making and strategic planning.', 'The accelerating volume of data sources, and subsequently data, has made data science is one of the fastest growing field across every industry.', 'As a result, it is no surprise that the role of the data scientist was dubbed the “sexiest job of the 21st century” by Harvard Business Review.', 'Organizations are increasingly reliant on them to interpret data and provide actionable recommendations to improve business outcomes.', 'The data science lifecycle involves various roles, tools, and processes, which enables analysts to glean actionable insights.', 'Typically, a data science project undergoes the following stages:\n\nData ingestion: The lifecycle begins with the data collection, both raw structured and unstructured data from all relevant sources using a variety of methods.', 'These methods can include manual entry, web scraping, and real-time streaming data from systems and devices.', 'Data sources can include structured data, such as customer data, along with unstructured data like log files, video, audio, pictures, the Internet of Things (IoT), social media, and more.', 'Data storage and data processing: Since data can have different formats and structures, companies need to consider different storage systems based on the type of data that needs to be captured.', 'Data management teams help to set standards around data storage and structure, which facilitate workflows around analytics, machine learning and deep learning models.', 'This stage includes cleaning data, deduplicating, transforming and combining the data using ETL (extract, transform, load) jobs or other data integration technologies.', 'This data preparation is essential for promoting data quality before loading into a data warehouse, data lake, or other repository.', 'Data analysis: Here, data scientists conduct an exploratory data analysis to examine biases, patterns, ranges, and distributions of values within the data.', 'This data analytics exploration drives hypothesis generation for a/b testing.', 'It also allows analysts to determine the data’s relevance for use within modeling efforts for predictive analytics, machine learning, and/or deep learning.', 'Depending on a model’s accuracy, organizations can become reliant on these insights for business decision making, allowing them to drive more scalability.', 'Communicate: Finally, insights are presented as reports and other data visualizations that make the insights and their impact on business easier for business analysts and other decision-makers to understand.', 'A data science programming language such as R or Python includes components for generating visualizations; alternately, data scientists can use dedicated visualization tools.']

# %%
stop_words = set(stopwords.words('english'))#storing the stopwords in english in a set
words = word_tokenize(clean_text.lower())#tokenize the sentences into words and converting them into lowercase
filtered_words = [ word for word in words if word.isalnum() and word not in stop_words]# stores words with alhpa and numeric and not stopwords and word is used for mapping
print(filtered_words)
# Out:
# ['data', 'science', 'combines', 'math', 'statistics', 'specialized', 'programming', 'advanced', 'analytics', 'artificial', 'intelligence', 'ai', 'machine', 'learning', 'specific', 'subject', 'matter', 'expertise', 'uncover', 'actionable', 'insights', 'hidden', 'organization', 'data', 'insights', 'used', 'guide', 'decision', 'making', 'strategic', 'planning', 'accelerating', 'volume', 'data', 'sources', 'subsequently', 'data', 'made', 'data', 'science', 'one', 'fastest', 'growing', 'field', 'across', 'every', 'industry', 'result', 'surprise', 'role', 'data', 'scientist', 'dubbed', 'sexiest', 'job', '21st', 'century', 'harvard', 'business', 'review', 'organizations', 'increasingly', 'reliant', 'interpret', 'data', 'provide', 'actionable', 'recommendations', 'improve', 'business', 'outcomes', 'data', 'science', 'lifecycle', 'involves', 'various', 'roles', 'tools', 'processes', 'enables', 'analysts', 'glean', 'actionable', 'insights', 'typically', 'data', 'science', 'project', 'undergoes', 'following', 'stages', 'data', 'ingestion', 'lifecycle', 'begins', 'data', 'collection', 'raw', 'structured', 'unstructured', 'data', 'relevant', 'sources', 'using', 'variety', 'methods', 'methods', 'include', 'manual', 'entry', 'web', 'scraping', 'streaming', 'data', 'systems', 'devices', 'data', 'sources', 'include', 'structured', 'data', 'customer', 'data', 'along', 'unstructured', 'data', 'like', 'log', 'files', 'video', 'audio', 'pictures', 'internet', 'things', 'iot', 'social', 'media', 'data', 'storage', 'data', 'processing', 'since', 'data', 'different', 'formats', 'structures', 'companies', 'need', 'consider', 'different', 'storage', 'systems', 'based', 'type', 'data', 'needs', 'captured', 'data', 'management', 'teams', 'help', 'set', 'standards', 'around', 'data', 'storage', 'structure', 'facilitate', 'workflows', 'around', 'analytics', 'machine', 'learning', 'deep', 'learning', 'models', 'stage', 'includes', 'cleaning', 'data', 'deduplicating', 'transforming', 'combining', 'data', 'using', 'etl', 'extract', 'transform', 'load', 'jobs', 'data', 'integration', 'technologies', 'data', 'preparation', 'essential', 'promoting', 'data', 'quality', 'loading', 'data', 'warehouse', 'data', 'lake', 'repository', 'data', 'analysis', 'data', 'scientists', 'conduct', 'exploratory', 'data', 'analysis', 'examine', 'biases', 'patterns', 'ranges', 'distributions', 'values', 'within', 'data', 'data', 'analytics', 'exploration', 'drives', 'hypothesis', 'generation', 'testing', 'also', 'allows', 'analysts', 'determine', 'data', 'relevance', 'use', 'within', 'modeling', 'efforts', 'predictive', 'analytics', 'machine', 'learning', 'deep', 'learning', 'depending', 'model', 'accuracy', 'organizations', 'become', 'reliant', 'insights', 'business', 'decision', 'making', 'allowing', 'drive', 'scalability', 'communicate', 'finally', 'insights', 'presented', 'reports', 'data', 'visualizations', 'make', 'insights', 'impact', 'business', 'easier', 'business', 'analysts', 'understand', 'data', 'science', 'programming', 'language', 'r', 'python', 'includes', 'components', 'generating', 'visualizations', 'alternately', 'data', 'scientists', 'use', 'dedicated', 'visualization', 'tools']

# %%
word_frequencies = {}
for word in filtered_words:
    if word not in word_frequencies:
        word_frequencies[word] = 1
    else:
        word_frequencies[word] += 1

# %%
word_frequencies
# Out:
# {'data': 39,
#  'science': 5,
#  'combines': 1,
#  'math': 1,
#  'statistics': 1,
#  'specialized': 1,
#  'programming': 2,
#  'advanced': 1,
#  'analytics': 4,
#  'artificial': 1,
#  'intelligence': 1,
#  'ai': 1,
#  'machine': 3,
#  'learning': 5,
#  'specific': 1,
#  'subject': 1,
#  'matter': 1,
#  'expertise': 1,
#  'uncover': 1,
#  'actionable': 3,
#  'insights': 6,
#  'hidden': 1,
#  'organization': 1,
#  'used': 1,
#  'guide': 1,
#  'decision': 2,
#  'making': 2,
#  'strategic': 1,
#  'planning': 1,
#  'accelerating': 1,
#  'volume': 1,
#  'sources': 3,
#  'subsequently': 1,
#  'made': 1,
#  'one': 1,
#  'fastest': 1,
#  'growing': 1,
#  'field': 1,
#  'across': 1,
#  'every': 1,
#  'industry': 1,
#  'result': 1,
#  'surprise': 1,
#  'role': 1,
#  'scientist': 1,
#  'dubbed': 1,
#  'sexiest': 1,
#  'job': 1,
#  '21st': 1,
#  'century': 1,
#  'harvard': 1,
#  'business': 5,
#  'review': 1,
#  'organizations': 2,
#  'increasingly': 1,
#  'reliant': 2,
#  'interpret': 1,
#  'provide': 1,
#  'recommendations': 1,
#  'improve': 1,
#  'outcomes': 1,
#  'lifecycle': 2,
#  'involves': 1,
#  'various': 1,
#  'roles': 1,
#  'tools': 2,
#  'processes': 1,
#  'enables': 1,
#  'analysts': 3,
#  'glean': 1,
#  'typically': 1,
#  'project': 1,
#  'undergoes': 1,
#  'following': 1,
#  'stages': 1,
#  'ingestion': 1,
#  'begins': 1,
#  'collection': 1,
#  'raw': 1,
#  'structured': 2,
#  'unstructured': 2,
#  'relevant': 1,
#  'using': 2,
#  'variety': 1,
#  'methods': 2,
#  'include': 2,
#  'manual': 1,
#  'entry': 1,
#  'web': 1,
#  'scraping': 1,
#  'streaming': 1,
#  'systems': 2,
#  'devices': 1,
#  'customer': 1,
#  'along': 1,
#  'like': 1,
#  'log': 1,
#  'files': 1,
#  'video': 1,
#  'audio': 1,
#  'pictures': 1,
#  'internet': 1,
#  'things': 1,
#  'iot': 1,
#  'social': 1,
#  'media': 1,
#  'storage': 3,
#  'processing': 1,
#  'since': 1,
#  'different': 2,
#  'formats': 1,
#  'structures': 1,
#  'companies': 1,
#  'need': 1,
#  'consider': 1,
#  'based': 1,
#  'type': 1,
#  'needs': 1,
#  'captured': 1,
#  'management': 1,
#  'teams': 1,
#  'help': 1,
#  'set': 1,
#  'standards': 1,
#  'around': 2,
#  'structure': 1,
#  'facilitate': 1,
#  'workflows': 1,
#  'deep': 2,
#  'models': 1,
#  'stage': 1,
#  'includes': 2,
#  'cleaning': 1,
#  'deduplicating': 1,
#  'transforming': 1,
#  'combining': 1,
#  'etl': 1,
#  'extract': 1,
#  'transform': 1,
#  'load': 1,
#  'jobs': 1,
#  'integration': 1,
#  'technologies': 1,
#  'preparation': 1,
#  'essential': 1,
#  'promoting': 1,
#  'quality': 1,
#  'loading': 1,
#  'warehouse': 1,
#  'lake': 1,
#  'repository': 1,
#  'analysis': 2,
#  'scientists': 2,
#  'conduct': 1,
#  'exploratory': 1,
#  'examine': 1,
#  'biases': 1,
#  'patterns': 1,
#  'ranges': 1,
#  'distributions': 1,
#  'values': 1,
#  'within': 2,
#  'exploration': 1,
#  'drives': 1,
#  'hypothesis': 1,
#  'generation': 1,
#  'testing': 1,
#  'also': 1,
#  'allows': 1,
#  'determine': 1,
#  'relevance': 1,
#  'use': 2,
#  'modeling': 1,
#  'efforts': 1,
#  'predictive': 1,
#  'depending': 1,
#  'model': 1,
#  'accuracy': 1,
#  'become': 1,
#  'allowing': 1,
#  'drive': 1,
#  'scalability': 1,
#  'communicate': 1,
#  'finally': 1,
#  'presented': 1,
#  'reports': 1,
#  'visualizations': 2,
#  'make': 1,
#  'impact': 1,
#  'easier': 1,
#  'understand': 1,
#  'language': 1,
#  'r': 1,
#  'python': 1,
#  'components': 1,
#  'generating': 1,
#  'alternately': 1,
#  'dedicated': 1,
#  'visualization': 1}

# %%
max_frequency = max(word_frequencies.values())
for word in word_frequencies:
    word_frequencies [word] = word_frequencies[word]/max_frequency
sentence_score = {}
for sentence in sentences:
    for word in word_tokenize(sentence.lower()):
        for word in word_frequencies:
            if len(sentence.split())<30:
                if sentence not in sentence_score:
                    sentence_score[sentence] = word_frequencies[word]
                else:
                    sentence_score[sentence] += word_frequencies[word]
print(sentence_score)
# Out:
# {'These insights can be used to guide decision making and strategic planning.': 96.33333333333383, 'The accelerating volume of data sources, and subsequently data, has made data science is one of the fastest growing field across every industry.': 192.66666666665847, 'As a result, it is no surprise that the role of the data scientist was dubbed the “sexiest job of the 21st century” by Harvard Business Review.': 229.71794871793668, 'Organizations are increasingly reliant on them to interpret data and provide actionable recommendations to improve business outcomes.': 133.38461538461334, 'The data science lifecycle involves various roles, tools, and processes, which enables analysts to glean actionable insights.': 155.61538461538026, 'These methods can include manual entry, web scraping, and real-time streaming data from systems and devices.': 140.79487179486898, 'Data sources can include structured data, such as customer data, along with unstructured data like log files, video, audio, pictures, the Internet of Things (IoT), social media, and more.': 296.4102564102644, 'Data management teams help to set standards around data storage and structure, which facilitate workflows around analytics, machine learning and deep learning models.': 192.66666666665847, 'This stage includes cleaning data, deduplicating, transforming and combining the data using ETL (extract, transform, load) jobs or other data integration technologies.': 214.8974358974254, 'This data preparation is essential for promoting data quality before loading into a data warehouse, data lake, or other repository.': 170.43589743589155, 'Data analysis: Here, data scientists conduct an exploratory data analysis to examine biases, patterns, ranges, and distributions of values within the data.': 207.48717948716975, 'This data analytics exploration drives hypothesis generation for a/b testing.': 81.51282051282189, 'It also allows analysts to determine the data’s relevance for use within modeling efforts for predictive analytics, machine learning, and/or deep learning.': 200.0769230769141, 'Depending on a model’s accuracy, organizations can become reliant on these insights for business decision making, allowing them to drive more scalability.': 200.0769230769141, 'Communicate: Finally, insights are presented as reports and other data visualizations that make the insights and their impact on business easier for business analysts and other decision-makers to understand.': 237.12820512819232, 'A data science programming language such as R or Python includes components for generating visualizations; alternately, data scientists can use dedicated visualization tools.': 192.66666666665847}

# %%
Summary_Sentence = heapq.nlargest(2,sentence_score,key=sentence_score.get)
Summary = "".join(Summary_Sentence)
print(Summary)
# Out:
# Data sources can include structured data, such as customer data, along with unstructured data like log files, video, audio, pictures, the Internet of Things (IoT), social media, and more.Communicate: Finally, insights are presented as reports and other data visualizations that make the insights and their impact on business easier for business analysts and other decision-makers to understand.
