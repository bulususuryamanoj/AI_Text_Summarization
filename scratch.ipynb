# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\SURYA
# [nltk_data]     MANOJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\SURYA
# [nltk_data]     MANOJ\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize
import re
import heapq

# %%
text ='''Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge from potentially noisy, structured, or unstructured data.[2]

Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]

Data science is "a concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data.[5] It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.[6] However, data science is different from computer science and information science. Turing Award winner Jim Gray imagined data science as a "fourth paradigm" of science (empirical, theoretical, computational, and now data-driven) and asserted that "everything about science is changing because of the impact of information technology" and the data deluge.[7][8]

Data science is often described as a multidisciplinary field because it draws on techniques from diverse areas, such as computer science, statistics, information science, and other subject-specific disciplines. Some researchers say that the combination of the different fields is similar to how information science was decades ago (Mayernik, 2023). These similarities help us understand how data science became its own field of study. [9]

A data scientist is a professional who creates programming code and combines it with statistical knowledge to summarize data.[10]'''

# %%
clean_text = re.sub(r'\[[0-9]*\]','',text)
clean_text = re.sub(r'\St','',clean_text)

# %%
sentences = sent_tokenize(clean_text)
print(sentences)
# Out:
# ['Da science is an ierdisciplinary academic field th uses iics, scieific comping, scieific mhods, processing, scieific visualizion, algorhms and syems to era or erapole knowledge from peially noisy, ruured, or unruured da.', 'Da science also iegres domain knowledge from the underlying applicion domain (e.g., nural sciences, informion technology, and medicine).', 'Da science is muifaced and can be described as a science, a research paradigm, a research mhod, a discipline, a workflow, and a profession.', 'Da science is "a conce to unify iics, da analysis, informics, and their reled mhods" to "underand and analyze aual phenomena" wh da.', 'uses techniques and theories drawn from many fields whin the coe of mhemics, iics, comper science, informion science, and domain knowledge.', 'However, da science is differe from comper science and informion science.', 'Turing Award winner Jim Gray imagined da science as a "fouh paradigm" of science (empirical, theorical, compional, and now da-driven)
# ...

# %%
stop_words = set(stopwords.words('english'))#storing the stopwords in english in a set
words = word_tokenize(clean_text.lower())#tokenize the sentences into words and converting them into lowercase
filtered_words = [ word for word in words if word.isalnum() and word not in stop_words]# stores words with alhpa and numeric and not stopwords and word is used for mapping
print(filtered_words)
# Out:
# ['da', 'science', 'ierdisciplinary', 'academic', 'field', 'th', 'uses', 'iics', 'scieific', 'comping', 'scieific', 'mhods', 'processing', 'scieific', 'visualizion', 'algorhms', 'syems', 'era', 'erapole', 'knowledge', 'peially', 'noisy', 'ruured', 'unruured', 'da', 'da', 'science', 'also', 'iegres', 'domain', 'knowledge', 'underlying', 'applicion', 'domain', 'nural', 'sciences', 'informion', 'technology', 'medicine', 'da', 'science', 'muifaced', 'described', 'science', 'research', 'paradigm', 'research', 'mhod', 'discipline', 'workflow', 'profession', 'da', 'science', 'conce', 'unify', 'iics', 'da', 'analysis', 'informics', 'reled', 'mhods', 'underand', 'analyze', 'aual', 'phenomena', 'wh', 'da', 'uses', 'techniques', 'theories', 'drawn', 'many', 'fields', 'whin', 'coe', 'mhemics', 'iics', 'comper', 'science', 'informion', 'science', 'domain', 'knowledge', 'however', 'da', 'science', 'differe', 'comper', 'science', 'informion', 'science', 'turing', 'award', 'winner', 'jim', 'gray', 'i
# ...

# %%
word_frequencies = {}
for word in filtered_words:
    if word not in word_frequencies:
        word_frequencies[word] = 1
    else:
        word_frequencies[word] += 1

# %%
word_frequencies
# Out:
# {'da': 14,
#  'science': 18,
#  'ierdisciplinary': 1,
#  'academic': 1,
#  'field': 3,
#  'th': 3,
#  'uses': 2,
#  'iics': 4,
#  'scieific': 3,
#  'comping': 1,
#  'mhods': 2,
#  'processing': 1,
#  'visualizion': 1,
#  'algorhms': 1,
#  'syems': 1,
#  'era': 1,
#  'erapole': 1,
#  'knowledge': 4,
#  'peially': 1,
#  'noisy': 1,
#  'ruured': 1,
#  'unruured': 1,
#  'also': 1,
#  'iegres': 1,
#  'domain': 3,
#  'underlying': 1,
#  'applicion': 1,
#  'nural': 1,
#  'sciences': 1,
#  'informion': 6,
#  'technology': 2,
#  'medicine': 1,
#  'muifaced': 1,
#  'described': 2,
#  'research': 2,
#  'paradigm': 2,
#  'mhod': 1,
#  'discipline': 1,
#  'workflow': 1,
#  'profession': 1,
#  'conce': 1,
#  'unify': 1,
#  'analysis': 1,
#  'informics': 1,
#  'reled': 1,
#  'underand': 2,
#  'analyze': 1,
#  'aual': 1,
#  'phenomena': 1,
#  'wh': 2,
#  'techniques': 2,
#  'theories': 1,
#  'drawn': 1,
#  'many': 1,
#  'fields': 2,
#  'whin': 1,
#  'coe': 1,
#  'mhemics': 1,
#  'comper': 3,
# ...

# %%
max_frequency = max(word_frequencies.values())
for word in word_frequencies:
    word_frequencies [word] = word_frequencies[word]/max_frequency
sentence_score = {}
for sentence in sentences:
    for word in word_tokenize(sentence.lower()):
        for word in word_frequencies:
            if len(sentence.split())<30:
                if sentence not in sentence_score:
                    sentence_score[sentence] = word_frequencies[word]
                else:
                    sentence_score[sentence] += word_frequencies[word]
print(sentence_score)
# Out:
# {'Da science also iegres domain knowledge from the underlying applicion domain (e.g., nural sciences, informion technology, and medicine).': 221.3333333333247, 'Da science is muifaced and can be described as a science, a research paradigm, a research mhod, a discipline, a workflow, and a profession.': 276.6666666666514, 'Da science is "a conce to unify iics, da analysis, informics, and their reled mhods" to "underand and analyze aual phenomena" wh da.': 285.8888888888724, 'uses techniques and theories drawn from many fields whin the coe of mhemics, iics, comper science, informion science, and domain knowledge.': 239.77777777776706, 'However, da science is differe from comper science and informion science.': 119.88888888889082, 'Da science is oen described as a muidisciplinary field because  draws on techniques from diverse areas, such as comper science, iics, informion science, and her subje-specific disciplines.': 295.11111111109335, 'Some researchers say th the combinion of the dif
# ...

# %%
Summary_Sentence = heapq.nlargest(2,sentence_score,key=sentence_score.get)
Summary = "".join(Summary_Sentence)
print(Summary)
# Out:
# Da science is oen described as a muidisciplinary field because  draws on techniques from diverse areas, such as comper science, iics, informion science, and her subje-specific disciplines.Da science is "a conce to unify iics, da analysis, informics, and their reled mhods" to "underand and analyze aual phenomena" wh da.
